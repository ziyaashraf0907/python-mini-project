# %% [markdown]
# <a href="https://colab.research.google.com/github/ziyaashraf0907/python-mini-project/blob/main/Creating_Functions_to_Analyze_Data_using_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
from google.colab import drive

# %%
import pandas as pd

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
datasetpath = '/content/drive/MyDrive/matches_1930_2022.csv'

# %%
df = pd.read_csv(datasetpath)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 959                             NaN
# 960                             NaN
# 961                             NaN
# 962                             NaN
# 963                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 959                                                NaN            NaN
# 960                                                NaN            NaN
# 961                                                NaN            NaN
# 962                                                NaN            NaN
# 963                                                NaN            NaN
#
#             away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN  Walid Cheddira · 90+3                  NaN
# ..                    ...                    ...                  ...
# 959                   NaN                    NaN                  NaN
# 960                   NaN                    NaN                  NaN
# 961  Plácido Galindo · 70                    NaN                  NaN
# 962                   NaN                    NaN                  NaN
# 963                   NaN                    NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                  NaN
# 2                                                  NaN
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4    ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [964 rows x 44 columns]

# %%
df.columns
# Out:
# Index(['home_team', 'away_team', 'home_score', 'home_xg', 'home_penalty',
#        'away_score', 'away_xg', 'away_penalty', 'home_manager', 'home_captain',
#        'away_manager', 'away_captain', 'Attendance', 'Venue', 'Officials',
#        'Round', 'Date', 'Score', 'Referee', 'Notes', 'Host', 'Year',
#        'home_goal', 'away_goal', 'home_goal_long', 'away_goal_long',
#        'home_own_goal', 'away_own_goal', 'home_penalty_goal',
#        'away_penalty_goal', 'home_penalty_miss_long', 'away_penalty_miss_long',
#        'home_penalty_shootout_goal_long', 'away_penalty_shootout_goal_long',
#        'home_penalty_shootout_miss_long', 'away_penalty_shootout_miss_long',
#        'home_red_card', 'away_red_card', 'home_yellow_red_card',
#        'away_yellow_red_card', 'home_yellow_card_long',
#        'away_yellow_card_long', 'home_substitute_in_long',
#        'away_substitute_in_long'],
#       dtype='object')

# %%
df['home_team'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 964 entries, 0 to 963
# Series name: home_team
# Non-Null Count  Dtype
# --------------  -----
# 964 non-null    object
# dtypes: object(1)
# memory usage: 7.7+ KB

# %%
df['home_team'].value_counts()
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
df['Date'].value_counts()
# Out:
# Date
# 1958-06-15    8
# 1958-06-08    8
# 1934-05-27    8
# 1958-06-11    7
# 1938-06-05    6
#              ..
# 2006-07-08    1
# 2006-07-05    1
# 2006-07-04    1
# 1966-07-25    1
# 2022-12-18    1
# Name: count, Length: 378, dtype: int64

# %%
df['Score'].value_counts()
# Out:
# Score
# 1–0            118
# 2–1            107
# 1–1             75
# 2–0             71
# 0–0             66
#               ...
# (4) 2–2 (3)      1
# (3) 0–0 (2)      1
# (4) 2–2 (5)      1
# (4) 1–1 (3)      1
# 6–5              1
# Name: count, Length: 71, dtype: int64

# %%
ScoreAboveZero = df['Score']>'0-0'

# %%
df[ScoreAboveZero]
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# 5          England    France           1      2.4           NaN           2
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# 5        0.9           NaN  Gareth Southgate            Harry Kane  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long away_penalty_shootout_miss_long  \
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
# 5                               NaN                             NaN
# ..                              ...                             ...
# 959                             NaN                             NaN
# 960                             NaN                             NaN
# 961                             NaN                             NaN
# 962                             NaN                             NaN
# 963                             NaN                             NaN
#
#      home_red_card         away_red_card   home_yellow_red_card  \
# 1              NaN                   NaN                    NaN
# 2              NaN                   NaN                    NaN
# 3              NaN                   NaN                    NaN
# 4              NaN                   NaN  Walid Cheddira · 90+3
# 5              NaN                   NaN                    NaN
# ..             ...                   ...                    ...
# 959            NaN                   NaN                    NaN
# 960            NaN                   NaN                    NaN
# 961            NaN  Plácido Galindo · 70                    NaN
# 962            NaN                   NaN                    NaN
# 963            NaN                   NaN                    NaN
#
#     away_yellow_red_card                              home_yellow_card_long  \
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN  ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4                    NaN  ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# 5                    NaN                   ['90&rsquor;|1:2|Harry Maguire']
# ..                   ...                                                ...
# 959                  NaN                                                NaN
# 960                  NaN                                                NaN
# 961                  NaN                                                NaN
# 962                  NaN                                                NaN
# 963                  NaN                                                NaN
#
#                                  away_yellow_card_long  \
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# 5    ['43&rsquor;|0:1|Antoine Griezmann', '47&rsquo...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# 5    ['79&rsquor;|1:2|Raheem Sterling|for Bukayo Sa...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# 5    ['79&rsquor;|1:2|Kingsley Coman|for Ousmane De...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [929 rows x 44 columns]

# %%
df.shape
# Out:
# (964, 44)

# %%
ScoredByBrazil = df['home_team'] =='Brazil'

# %%
df[ScoreAboveZero & ScoredByBrazil]
# Out:
#     home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 11     Brazil  Korea Republic           4      3.6           NaN           1
# 34     Brazil     Switzerland           1      1.0           NaN           0
# 51     Brazil          Serbia           2      2.4           NaN           0
# 71     Brazil         Belgium           1      2.8           NaN           2
# 74     Brazil          Mexico           2      2.7           NaN           0
# ..        ...             ...         ...      ...           ...         ...
# 911    Brazil          Sweden           4      NaN           NaN           2
# 915    Brazil  Czechoslovakia           2      NaN           NaN           1
# 917    Brazil  Czechoslovakia           1      NaN           NaN           1
# 926    Brazil          Poland           6      NaN           NaN           5
# 951    Brazil         Bolivia           4      NaN           NaN           0
#
#      away_xg  away_penalty         home_manager               home_captain  \
# 11       0.5           NaN                 Tite               Thiago Silva
# 34       0.3           NaN                 Tite               Thiago Silva
# 51       0.2           NaN                 Tite               Thiago Silva
# 71       0.5           NaN                 Tite                    Miranda
# 74       0.7           NaN                 Tite               Thiago Silva
# ..       ...           ...                  ...                        ...
# 911      NaN           NaN       Ademar Pimenta                   Leônidas
# 915      NaN           NaN       Ademar Pimenta                   Leônidas
# 917      NaN           NaN       Ademar Pimenta  Martim Mércio da Silveira
# 926      NaN           NaN       Ademar Pimenta  Martim Mércio da Silveira
# 951      NaN           NaN  Pindaro De Carvalho                  Preguinho
#
#      ... home_penalty_shootout_miss_long away_penalty_shootout_miss_long  \
# 11   ...                             NaN                             NaN
# 34   ...                             NaN                             NaN
# 51   ...                             NaN                             NaN
# 71   ...                             NaN                             NaN
# 74   ...                             NaN                             NaN
# ..   ...                             ...                             ...
# 911  ...                             NaN                             NaN
# 915  ...                             NaN                             NaN
# 917  ...                             NaN                             NaN
# 926  ...                             NaN                             NaN
# 951  ...                             NaN                             NaN
#
#                               home_red_card  away_red_card  \
# 11                                      NaN            NaN
# 34                                      NaN            NaN
# 51                                      NaN            NaN
# 71                                      NaN            NaN
# 74                                      NaN            NaN
# ..                                      ...            ...
# 911                                     NaN            NaN
# 915                                     NaN            NaN
# 917  Zezé Procópio · 14|Arthur Machado · 89  Jan Říha · 89
# 926                                     NaN            NaN
# 951                                     NaN            NaN
#
#     home_yellow_red_card away_yellow_red_card  \
# 11                   NaN                  NaN
# 34                   NaN                  NaN
# 51                   NaN                  NaN
# 71                   NaN                  NaN
# 74                   NaN                  NaN
# ..                   ...                  ...
# 911                  NaN                  NaN
# 915                  NaN                  NaN
# 917                  NaN                  NaN
# 926                  NaN                  NaN
# 951                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 11                                                 NaN
# 34                             ['52&rsquor;|0:0|Fred']
# 51                                                 NaN
# 71   ['85&rsquor;|1:2|Fernandinho', '90&rsquor;|1:2...
# 74   ['43&rsquor;|0:0|Filipe Luís', '59&rsquor;|1:0...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
#                                  away_yellow_card_long  \
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 34                    ['50&rsquor;|0:0|Fabian Rieder']
# 51   ['7&rsquor;|0:0|Strahinja Pavlović', '49&rsquo...
# 71   ['47&rsquor;|0:2|Toby Alderweireld', '71&rsquo...
# 74   ['38&rsquor;|0:0|Edson Álvarez', '55&rsquor;|1...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
#                                home_substitute_in_long  \
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 34   ['46&rsquor;|0:0|Rodrygo|for Lucas Paquetá', '...
# 51   ['75&rsquor;|2:0|Fred|for Lucas Paquetá', '76&...
# 71   ['46&rsquor;|0:2|Roberto Firmino|for Willian',...
# 74   ['80&rsquor;|1:0|Fernandinho|for Paulinho', '8...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
#                                away_substitute_in_long
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 34   ['59&rsquor;|0:0|Edimilson Fernandes|for Ruben...
# 51   ['57&rsquor;|0:0|Ivan Ilić|for Nemanja Gudelj'...
# 71   ['83&rsquor;|1:2|Thomas Vermaelen|for Nacer Ch...
# 74   ['46&rsquor;|0:0|Miguel Layún|for Rafael Márqu...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
# [81 rows x 44 columns]

# %%
brazildf = df[ScoreAboveZero & ScoredByBrazil].sort_values(by='home_score',ascending=True)

# %%
brazildf
# Out:
#     home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 512    Brazil       Argentina           0      NaN           NaN           1
# 261    Brazil          France           0      NaN           NaN           1
# 695    Brazil          Poland           0      NaN           NaN           1
# 817    Brazil  Czechoslovakia           0      NaN           NaN           0
# 679    Brazil           Spain           0      NaN           NaN           0
# ..        ...             ...         ...      ...           ...         ...
# 887    Brazil          Mexico           5      NaN           NaN           0
# 831    Brazil          France           5      NaN           NaN           2
# 891    Brazil           Spain           6      NaN           NaN           1
# 926    Brazil          Poland           6      NaN           NaN           5
# 893    Brazil          Sweden           7      NaN           NaN           1
#
#      away_xg  away_penalty             home_manager  \
# 512      NaN           NaN       Sebastiao Lazaroni
# 261      NaN           NaN  Carlos Alberto Parreira
# 695      NaN           NaN            Mario Zagallo
# 817      NaN           NaN           Aymore Moreira
# 679      NaN           NaN         Claudio Coutinho
# ..       ...           ...                      ...
# 887      NaN           NaN             Zeze Moreira
# 831      NaN           NaN            Vicente Feola
# 891      NaN           NaN             Flavio Costa
# 926      NaN           NaN           Ademar Pimenta
# 893      NaN           NaN             Flavio Costa
#
#                   home_captain  ... home_penalty_shootout_miss_long  \
# 512              Ricardo Gomes  ...                             NaN
# 261                        NaN  ...                             NaN
# 695              Marinho Peres  ...                             NaN
# 817                Mauro Ramos  ...                             NaN
# 679               Émerson Leão  ...                             NaN
# ..                         ...  ...                             ...
# 887                      Bauer  ...                             NaN
# 831         Hilderaldo Bellini  ...                             NaN
# 891           Augusto da Costa  ...                             NaN
# 926  Martim Mércio da Silveira  ...                             NaN
# 893           Augusto da Costa  ...                             NaN
#
#     away_penalty_shootout_miss_long       home_red_card away_red_card  \
# 512                             NaN  Ricardo Gomes · 85           NaN
# 261                             NaN                 NaN           NaN
# 695                             NaN                 NaN           NaN
# 817                             NaN                 NaN           NaN
# 679                             NaN                 NaN           NaN
# ..                              ...                 ...           ...
# 887                             NaN                 NaN           NaN
# 831                             NaN                 NaN           NaN
# 891                             NaN                 NaN           NaN
# 926                             NaN                 NaN           NaN
# 893                             NaN                 NaN           NaN
#
#     home_yellow_red_card away_yellow_red_card  \
# 512                  NaN                  NaN
# 261                  NaN                  NaN
# 695                  NaN                  NaN
# 817                  NaN                  NaN
# 679                  NaN                  NaN
# ..                   ...                  ...
# 887                  NaN                  NaN
# 831                  NaN                  NaN
# 891                  NaN                  NaN
# 926                  NaN                  NaN
# 893                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 512  ['40&rsquor;|0:0|Ricardo Rocha', '50&rsquor;|0...
# 261  ['25&rsquor;|0:0|Cafú', '45&rsquor;|0:0|Juan',...
# 695                       ['76&rsquor;|0:1|Jairzinho']
# 817                                                NaN
# 679                                                NaN
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                           ['1&rsquor;|0:0|Bigode']
# 926                                                NaN
# 893                                                NaN
#
#                                  away_yellow_card_long  \
# 512  ['27&rsquor;|0:0|Pedro Monzón', '28&rsquor;|0:...
# 261  ['74&rsquor;|0:1|Willy Sagnol', '87&rsquor;|0:...
# 695               ['71&rsquor;|0:0|Henryk Kasperczak']
# 817                                                NaN
# 679                     ['1&rsquor;|0:0|Eugenio Leal']
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
#                                home_substitute_in_long  \
# 512  ['83&rsquor;|0:1|Silas Pereira', '83&rsquor;|0...
# 261  ['63&rsquor;|0:1|Adriano|for Juninho Pernambuc...
# 695   ['66&rsquor;|0:0|Mirandinha|for Ademir da Guia']
# 817                                                NaN
# 679  ['70&rsquor;|0:0|Gilberto Alves|for Nelinho', ...
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
#                                away_substitute_in_long
# 512  ['61&rsquor;|0:0|Gabriel Calderón|for Pedro Tr...
# 261  ['77&rsquor;|0:1|Sidney Govou|for Franck Ribér...
# 695  ['73&rsquor;|0:0|Lesław Ćmikiewicz|for Henryk ...
# 817                                                NaN
# 679  ['51&rsquor;|0:0|Antonio Biosca|for Migueli', ...
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
# [81 rows x 44 columns]

# %%
brazildf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81 entries, 512 to 893
# Data columns (total 44 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   home_team                        81 non-null     object
#  1   away_team                        81 non-null     object
#  2   home_score                       81 non-null     int64
#  3   home_xg                          7 non-null      float64
#  4   home_penalty                     0 non-null      float64
#  5   away_score                       81 non-null     int64
#  6   away_xg                          7 non-null      float64
#  7   away_penalty                     0 non-null      float64
#  8   home_manager                     81 non-null     object
#  9   home_captain                     59 non-null     object
#  10  away_manager                     81 non-null     object
#  11  away_captain                     59 non-null     object
#  12  Attendance                       81 non-null     int64
#  13  Venue                            81 non-null     object
#  14  Officials                        64 non-null     object
#  15  Round                            81 non-null     object
#  16  Date                             81 non-null     object
#  17  Score                            81 non-null     object
#  18  Referee                          64 non-null     object
#  19  Notes                            3 non-null      object
#  20  Host                             81 non-null     object
#  21  Year                             81 non-null     int64
#  22  home_goal                        71 non-null     object
#  23  away_goal                        38 non-null     object
#  24  home_goal_long                   71 non-null     object
#  25  away_goal_long                   38 non-null     object
#  26  home_own_goal                    2 non-null      object
#  27  away_own_goal                    2 non-null      object
#  28  home_penalty_goal                8 non-null      object
#  29  away_penalty_goal                8 non-null      object
#  30  home_penalty_miss_long           0 non-null      object
#  31  away_penalty_miss_long           0 non-null      object
#  32  home_penalty_shootout_goal_long  0 non-null      object
#  33  away_penalty_shootout_goal_long  0 non-null      object
#  34  home_penalty_shootout_miss_long  0 non-null      object
#  35  away_penalty_shootout_miss_long  0 non-null      object
#  36  home_red_card                    4 non-null      object
#  37  away_red_card                    3 non-null      object
#  38  home_yellow_red_card             1 non-null      object
#  39  away_yellow_red_card             3 non-null      object
#  40  home_yellow_card_long            43 non-null     object
#  41  away_yellow_card_long            47 non-null     object
#  42  home_substitute_in_long          51 non-null     object
#  43  away_substitute_in_long          55 non-null     object
# dtypes: float64(4), int64(4), object(36)
# memory usage: 28.5+ KB

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
brazildf.plot(x='home_score',y='away_score',kind = 'scatter')
plt.xlabel('Home Score')
plt.ylabel('Away Score')
plt.legend('Takeaway')
plt.title('Brazil Matches')
plt.show()

# %%
brazildf.plot(x='Year',y='home_score',kind = 'hexbin')
plt.xlabel('Year')
plt.ylabel('home score')
plt.legend('Takeaway')
plt.title('Brazil Matches')
plt.show()

# %%
 def AnalyzeFrance():
    matchesplayed = df['home_team'].value_counts()['France']
    print(f'Total number of matches played by France is:{matchesplayed}')

# %%
AnalyzeFrance()
# Out:
# Total number of matches played by France is:38

# %%
def AnalyzeTown():
    TownData = df['home_team'].value_counts()
    for _ in TownData.index:
     print(f'total number of matches played by (_) is :{TownData[_]}')

# %%
AnalyzeTown()
# Out:
# total number of matches played by (_) is :85
# total number of matches played by (_) is :59
# total number of matches played by (_) is :57
# total number of matches played by (_) is :40
# total number of matches played by (_) is :40
# total number of matches played by (_) is :38
# total number of matches played by (_) is :38
# total number of matches played by (_) is :34
# total number of matches played by (_) is :33
# total number of matches played by (_) is :33
# total number of matches played by (_) is :30
# total number of matches played by (_) is :23
# total number of matches played by (_) is :21
# total number of matches played by (_) is :20
# total number of matches played by (_) is :18
# total number of matches played by (_) is :18
# total number of matches played by (_) is :18
# total number of matches played by (_) is :18
# total number of matches played by (_) is :16
# total number of matches played by (_) is :16
# total number of matches played by (_) is :16
# total number of matches played by (_) is :15
# total number of matches played by (_) is :14
# total number of matches played by (_) is :13
# total number of matches played by (_) is :12
# total number of matches played by (_) is :11
# total number of matches played by (_) is :11
# total number of matches played by (_) is :10
# total number of matches played by (_) is :10
# total number of matches played by (_) is :10
# total number of matches played by (_) is :9
# total number of matches played by (_) is :9
# total number of matches played by (_) is :8
# total number of matches played by (_) is :8
# total number of matches played by (_) is :8
# total number of matches played by (_) is :8
# total number of matches played by (_) is :8
# total number of matches played by (_) is :7
# total number of matches played by (_) is :7
# total number of matches played by (_) is :6
# total number of matches played by (_) is :6
# total number of matches played by (_) is :6
# total number of matches played by (_) is :6
# total number of matches played by (_) is :5
# total number of matches played by (_) is :5
# total number of matches played by (_) is :5
# total number of matches played by (_) is :5
# total number of matches played by (_) is :5
# total number of matches played by (_) is :5
# total number of matches played by (_) is :4
# total number of matches played by (_) is :4
# total number of matches played by (_) is :4
# total number of matches played by (_) is :3
# total number of matches played by (_) is :3
# total number of matches played by (_) is :3
# total number of matches played by (_) is :3
# total number of matches played by (_) is :3
# total number of matches played by (_) is :2
# total number of matches played by (_) is :2
# total number of matches played by (_) is :2
# total number of matches played by (_) is :2
# total number of matches played by (_) is :2
# total number of matches played by (_) is :2
# total number of matches played by (_) is :2
# total number of matches played by (_) is :2
# total number of matches played by (_) is :2
# total number of matches played by (_) is :1
# total number of matches played by (_) is :1
# total number of matches played by (_) is :1
# total number of matches played by (_) is :1
# total number of matches played by (_) is :1
# total number of matches played by (_) is :1
# total number of matches played by (_) is :1
# total number of matches played by (_) is :1
# total number of matches played by (_) is :1
# total number of matches played by (_) is :1
# total number of matches played by (_) is :1
# total number of matches played by (_) is :1
# total number of matches played by (_) is :1
# total number of matches played by (_) is :1
# total number of matches played by (_) is :1
# total number of matches played by (_) is :1

# %%
# %matplotlib inline

# %%
def matchesplayedbytown():
    Townname = []
    matchesplayed = []
    TownData = df['home_team'].value_counts()
    for _ in TownData.index:
     if TownData[_] >30:
       Townname.append(_)
       matchesplayed.append(TownData[_])
    plt.bar(matchesplayed,Townname)
    plt.xlabel('Town Name')
    plt.ylabel('Matches Played')
    plt.title('Matches Played by Town')
    plt.show()

# %%
matchesplayedbytown()

# %%
Town30 = df['home_team'].value_counts()>30
Town30
# Out:
# home_team
# Brazil                     True
# Argentina                  True
# Italy                      True
# England                    True
# Germany                    True
#                           ...
# Jamaica                   False
# FR Yugoslavia             False
# Angola                    False
# Trinidad and Tobago       False
# Bosnia and Herzegovina    False
# Name: count, Length: 82, dtype: bool

# %%
Townname = []
matchesplayed = []
TownData = df['home_team'].value_counts()
for _ in TownData.index:
  if TownData[_] >30:
    Townname.append(_)
    matchesplayed.append(TownData[_])

# %%
Townname
# Out:
# ['Brazil',
#  'Argentina',
#  'Italy',
#  'England',
#  'Germany',
#  'France',
#  'West Germany',
#  'Spain',
#  'Netherlands',
#  'Uruguay']

# %%
from matplotlib import pyplot as plt

# %%
plt.bar(matchesplayed,Townname)
plt.xlabel('Town Name')
plt.ylabel('Matches Played')
plt.title('Matches Played by Town')
plt.show()

# %%
df['home_team'].value_counts()
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
def matchesplayedbyTown2():
    teamAbove30 = df['home_team'].value_counts()>30
    Above30 = df['home_team'].value_counts()
    filteredData = Above30[Above30 > 30]
    filteredData.plot(kind = 'bar')

# %%
matchesplayedbyTown2()

# %%
teamAbove30 = df['home_team'].value_counts()>30
teamAbove30
# Out:
# home_team
# Brazil                     True
# Argentina                  True
# Italy                      True
# England                    True
# Germany                    True
#                           ...
# Jamaica                   False
# FR Yugoslavia             False
# Angola                    False
# Trinidad and Tobago       False
# Bosnia and Herzegovina    False
# Name: count, Length: 82, dtype: bool

# %%
Above30 = df['home_team'].value_counts()

# %%
filteredData = Above30[Above30 > 30]

# %%
filteredData.plot(kind = 'bar')
# Out:
# <Axes: xlabel='home_team'>

# %%
df['home_team'].value_counts()
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
filteredData = df['home_team'].value_counts()

# %%
f2 = filteredData[filteredData > 40].index

# %%
f2
# Out:
# Index(['Brazil', 'Argentina', 'Italy'], dtype='object', name='home_team')

# %%
df[df['home_team'].isin(f2)]
# Out:
#      home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 0    Argentina          France           3      3.3           4.0           3
# 3    Argentina         Croatia           3      2.3           NaN           0
# 11      Brazil  Korea Republic           4      3.6           NaN           1
# 15   Argentina       Australia           2      1.6           NaN           1
# 34      Brazil     Switzerland           1      1.0           NaN           0
# ..         ...             ...         ...      ...           ...         ...
# 948  Argentina   United States           6      NaN           NaN           1
# 949  Argentina           Chile           3      NaN           NaN           1
# 951     Brazil         Bolivia           4      NaN           NaN           0
# 954  Argentina          Mexico           6      NaN           NaN           3
# 959  Argentina          France           1      NaN           NaN           0
#
#      away_xg  away_penalty         home_manager     home_captain  ...  \
# 0        2.2           2.0       Lionel Scaloni     Lionel Messi  ...
# 3        0.5           NaN       Lionel Scaloni     Lionel Messi  ...
# 11       0.5           NaN                 Tite     Thiago Silva  ...
# 15       0.6           NaN       Lionel Scaloni     Lionel Messi  ...
# 34       0.3           NaN                 Tite     Thiago Silva  ...
# ..       ...           ...                  ...              ...  ...
# 948      NaN           NaN     Francisco Olazar  Manuel Ferreira  ...
# 949      NaN           NaN     Francisco Olazar  Manuel Ferreira  ...
# 951      NaN           NaN  Pindaro De Carvalho        Preguinho  ...
# 954      NaN           NaN     Francisco Olazar     Ángel Bossio  ...
# 959      NaN           NaN     Francisco Olazar  Manuel Ferreira  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 3                               NaN
# 11                              NaN
# 15                              NaN
# 34                              NaN
# ..                              ...
# 948                             NaN
# 949                             NaN
# 951                             NaN
# 954                             NaN
# 959                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 3                                                  NaN            NaN
# 11                                                 NaN            NaN
# 15                                                 NaN            NaN
# 34                                                 NaN            NaN
# ..                                                 ...            ...
# 948                                                NaN            NaN
# 949                                                NaN            NaN
# 951                                                NaN            NaN
# 954                                                NaN            NaN
# 959                                                NaN            NaN
#
#     away_red_card home_yellow_red_card away_yellow_red_card  \
# 0             NaN                  NaN                  NaN
# 3             NaN                  NaN                  NaN
# 11            NaN                  NaN                  NaN
# 15            NaN                  NaN                  NaN
# 34            NaN                  NaN                  NaN
# ..            ...                  ...                  ...
# 948           NaN                  NaN                  NaN
# 949           NaN                  NaN                  NaN
# 951           NaN                  NaN                  NaN
# 954           NaN                  NaN                  NaN
# 959           NaN                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 11                                                 NaN
# 15                                                 NaN
# 34                             ['52&rsquor;|0:0|Fred']
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 15   ['15&rsquor;|0:0|Jackson Irvine', '38&rsquor;|...
# 34                    ['50&rsquor;|0:0|Fabian Rieder']
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 15   ['50&rsquor;|1:0|Lisandro Martínez|for Papu Gó...
# 34   ['46&rsquor;|0:0|Rodrygo|for Lucas Paquetá', '...
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 15   ['58&rsquor;|2:0|Craig Goodwin|for Riley McGre...
# 34   ['59&rsquor;|0:0|Edimilson Fernandes|for Ruben...
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
# [201 rows x 44 columns]

# %%
df2 = df[df['home_team'].isin(f2)]

# %%
df2
# Out:
#      home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 0    Argentina          France           3      3.3           4.0           3
# 3    Argentina         Croatia           3      2.3           NaN           0
# 11      Brazil  Korea Republic           4      3.6           NaN           1
# 15   Argentina       Australia           2      1.6           NaN           1
# 34      Brazil     Switzerland           1      1.0           NaN           0
# ..         ...             ...         ...      ...           ...         ...
# 948  Argentina   United States           6      NaN           NaN           1
# 949  Argentina           Chile           3      NaN           NaN           1
# 951     Brazil         Bolivia           4      NaN           NaN           0
# 954  Argentina          Mexico           6      NaN           NaN           3
# 959  Argentina          France           1      NaN           NaN           0
#
#      away_xg  away_penalty         home_manager     home_captain  ...  \
# 0        2.2           2.0       Lionel Scaloni     Lionel Messi  ...
# 3        0.5           NaN       Lionel Scaloni     Lionel Messi  ...
# 11       0.5           NaN                 Tite     Thiago Silva  ...
# 15       0.6           NaN       Lionel Scaloni     Lionel Messi  ...
# 34       0.3           NaN                 Tite     Thiago Silva  ...
# ..       ...           ...                  ...              ...  ...
# 948      NaN           NaN     Francisco Olazar  Manuel Ferreira  ...
# 949      NaN           NaN     Francisco Olazar  Manuel Ferreira  ...
# 951      NaN           NaN  Pindaro De Carvalho        Preguinho  ...
# 954      NaN           NaN     Francisco Olazar     Ángel Bossio  ...
# 959      NaN           NaN     Francisco Olazar  Manuel Ferreira  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 3                               NaN
# 11                              NaN
# 15                              NaN
# 34                              NaN
# ..                              ...
# 948                             NaN
# 949                             NaN
# 951                             NaN
# 954                             NaN
# 959                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 3                                                  NaN            NaN
# 11                                                 NaN            NaN
# 15                                                 NaN            NaN
# 34                                                 NaN            NaN
# ..                                                 ...            ...
# 948                                                NaN            NaN
# 949                                                NaN            NaN
# 951                                                NaN            NaN
# 954                                                NaN            NaN
# 959                                                NaN            NaN
#
#     away_red_card home_yellow_red_card away_yellow_red_card  \
# 0             NaN                  NaN                  NaN
# 3             NaN                  NaN                  NaN
# 11            NaN                  NaN                  NaN
# 15            NaN                  NaN                  NaN
# 34            NaN                  NaN                  NaN
# ..            ...                  ...                  ...
# 948           NaN                  NaN                  NaN
# 949           NaN                  NaN                  NaN
# 951           NaN                  NaN                  NaN
# 954           NaN                  NaN                  NaN
# 959           NaN                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 11                                                 NaN
# 15                                                 NaN
# 34                             ['52&rsquor;|0:0|Fred']
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 15   ['15&rsquor;|0:0|Jackson Irvine', '38&rsquor;|...
# 34                    ['50&rsquor;|0:0|Fabian Rieder']
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 15   ['50&rsquor;|1:0|Lisandro Martínez|for Papu Gó...
# 34   ['46&rsquor;|0:0|Rodrygo|for Lucas Paquetá', '...
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 15   ['58&rsquor;|2:0|Craig Goodwin|for Riley McGre...
# 34   ['59&rsquor;|0:0|Edimilson Fernandes|for Ruben...
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
# [201 rows x 44 columns]

# %%
df2['home_team'].value_counts()
# Out:
# home_team
# Brazil       85
# Argentina    59
# Italy        57
# Name: count, dtype: int64

# %%
# %matplotlib inline

# %%
df2.plot(x="home_team",y="home_xg",kind="bar")
# Out:
# <Axes: xlabel='home_team'>

# %%
f3 = df2["home_xg"]> 2.5

# %%
df3 = df2[f3]

# %%
df3
# Out:
#      home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 0    Argentina          France           3      3.3           4.0           3
# 11      Brazil  Korea Republic           4      3.6           NaN           1
# 71      Brazil         Belgium           1      2.8           NaN           2
# 74      Brazil          Mexico           2      2.7           NaN           0
# 102     Brazil      Costa Rica           2      2.6           NaN           0
#
#      away_xg  away_penalty    home_manager  home_captain  ...  \
# 0        2.2           2.0  Lionel Scaloni  Lionel Messi  ...
# 11       0.5           NaN            Tite  Thiago Silva  ...
# 71       0.5           NaN            Tite       Miranda  ...
# 74       0.7           NaN            Tite  Thiago Silva  ...
# 102      0.1           NaN            Tite  Thiago Silva  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 11                              NaN
# 71                              NaN
# 74                              NaN
# 102                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 11                                                 NaN            NaN
# 71                                                 NaN            NaN
# 74                                                 NaN            NaN
# 102                                                NaN            NaN
#
#     away_red_card home_yellow_red_card away_yellow_red_card  \
# 0             NaN                  NaN                  NaN
# 11            NaN                  NaN                  NaN
# 71            NaN                  NaN                  NaN
# 74            NaN                  NaN                  NaN
# 102           NaN                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 11                                                 NaN
# 71   ['85&rsquor;|1:2|Fernandinho', '90&rsquor;|1:2...
# 74   ['43&rsquor;|0:0|Filipe Luís', '59&rsquor;|1:0...
# 102  ['81&rsquor;|0:0|Philippe Coutinho', '81&rsquo...
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 71   ['47&rsquor;|0:2|Toby Alderweireld', '71&rsquo...
# 74   ['38&rsquor;|0:0|Edson Álvarez', '55&rsquor;|1...
# 102                   ['84&rsquor;|0:0|Johnny Acosta']
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 71   ['46&rsquor;|0:2|Roberto Firmino|for Willian',...
# 74   ['80&rsquor;|1:0|Fernandinho|for Paulinho', '8...
# 102  ['46&rsquor;|0:0|Douglas Costa|for Willian', '...
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 71   ['83&rsquor;|1:2|Thomas Vermaelen|for Nacer Ch...
# 74   ['46&rsquor;|0:0|Miguel Layún|for Rafael Márqu...
# 102  ['54&rsquor;|0:0|Christian Bolaños|for Marco U...
#
# [5 rows x 44 columns]

# %%
df3.plot(x="home_team",y="home_xg",kind="bar")
# Out:
# <Axes: xlabel='home_team'>

# %%
from matplotlib import pyplot as plt

# %%
df3.plot(x="home_team",y="home_xg",kind="bar")
plt.xlabel("home_team")
plt.ylabel("home_xg")
plt.title("Home Team estimated goals")
plt.show()

# %%
df3
# Out:
#      home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 0    Argentina          France           3      3.3           4.0           3
# 11      Brazil  Korea Republic           4      3.6           NaN           1
# 71      Brazil         Belgium           1      2.8           NaN           2
# 74      Brazil          Mexico           2      2.7           NaN           0
# 102     Brazil      Costa Rica           2      2.6           NaN           0
#
#      away_xg  away_penalty    home_manager  home_captain  ...  \
# 0        2.2           2.0  Lionel Scaloni  Lionel Messi  ...
# 11       0.5           NaN            Tite  Thiago Silva  ...
# 71       0.5           NaN            Tite       Miranda  ...
# 74       0.7           NaN            Tite  Thiago Silva  ...
# 102      0.1           NaN            Tite  Thiago Silva  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 11                              NaN
# 71                              NaN
# 74                              NaN
# 102                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 11                                                 NaN            NaN
# 71                                                 NaN            NaN
# 74                                                 NaN            NaN
# 102                                                NaN            NaN
#
#     away_red_card home_yellow_red_card away_yellow_red_card  \
# 0             NaN                  NaN                  NaN
# 11            NaN                  NaN                  NaN
# 71            NaN                  NaN                  NaN
# 74            NaN                  NaN                  NaN
# 102           NaN                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 11                                                 NaN
# 71   ['85&rsquor;|1:2|Fernandinho', '90&rsquor;|1:2...
# 74   ['43&rsquor;|0:0|Filipe Luís', '59&rsquor;|1:0...
# 102  ['81&rsquor;|0:0|Philippe Coutinho', '81&rsquo...
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 71   ['47&rsquor;|0:2|Toby Alderweireld', '71&rsquo...
# 74   ['38&rsquor;|0:0|Edson Álvarez', '55&rsquor;|1...
# 102                   ['84&rsquor;|0:0|Johnny Acosta']
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 71   ['46&rsquor;|0:2|Roberto Firmino|for Willian',...
# 74   ['80&rsquor;|1:0|Fernandinho|for Paulinho', '8...
# 102  ['46&rsquor;|0:0|Douglas Costa|for Willian', '...
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 71   ['83&rsquor;|1:2|Thomas Vermaelen|for Nacer Ch...
# 74   ['46&rsquor;|0:0|Miguel Layún|for Rafael Márqu...
# 102  ['54&rsquor;|0:0|Christian Bolaños|for Marco U...
#
# [5 rows x 44 columns]

# %%
df3.plot(x="home_team",y=["home_score","home_xg"],kind="bar",color = ["pink","skyblue"])
plt.xlabel("Home team")
plt.ylabel("Home XG")
plt.title("Home Team estimated goals ")
plt.show()

# %%
#groupby
df.groupby("home_team")["home_score"].mean()
# Out:
# home_team
# Algeria         0.833333
# Angola          0.000000
# Argentina       2.050847
# Australia       1.000000
# Austria         2.000000
#                   ...
# Uruguay         2.060606
# Wales           0.666667
# West Germany    2.026316
# Yugoslavia      2.562500
# Zaire           0.000000
# Name: home_score, Length: 82, dtype: float64

# %%
dg = df.groupby("home_team")["home_xg"]

# %%
print(dg.mean())
# Out:
# home_team
# Algeria              NaN
# Angola               NaN
# Argentina       1.842857
# Australia       0.750000
# Austria              NaN
#                   ...
# Uruguay         1.240000
# Wales           0.600000
# West Germany         NaN
# Yugoslavia           NaN
# Zaire                NaN
# Name: home_xg, Length: 82, dtype: float64

# %%
das = pd.DataFrame({
      'Branch':['CSE','ECE','CSE','BBA','BBA'],
      'Name':['virat','suresh','prasad','priya','leela'],
      'Salary':[10000,20000,30000,15000,13000]

})

# %%
das
# Out:
#   Branch    Name  Salary
# 0    CSE   virat   10000
# 1    ECE  suresh   20000
# 2    CSE  prasad   30000
# 3    BBA   priya   15000
# 4    BBA   leela   13000

# %%
sv = das.groupby('Branch')['Salary']

# %%
das.describe()
# Out:
#              Salary
# count      5.000000
# mean   17600.000000
# std     7829.431652
# min    10000.000000
# 25%    13000.000000
# 50%    15000.000000
# 75%    20000.000000
# max    30000.000000

# %%
sv.agg(['mean','min'])
# Out:
#            mean    min
# Branch
# BBA     14000.0  13000
# CSE     20000.0  10000
# ECE     20000.0  20000

# %%
sv2=das.groupby(['Branch','Name'])['Salary']

# %%
sv2.max()
# Out:
# Branch  Name
# BBA     leela     13000
#         priya     15000
# CSE     prasad    30000
#         virat     10000
# ECE     suresh    20000
# Name: Salary, dtype: int64

# %%
import random

# %%
age = []
height = []
Weight = []

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 959                             NaN
# 960                             NaN
# 961                             NaN
# 962                             NaN
# 963                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 959                                                NaN            NaN
# 960                                                NaN            NaN
# 961                                                NaN            NaN
# 962                                                NaN            NaN
# 963                                                NaN            NaN
#
#             away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN  Walid Cheddira · 90+3                  NaN
# ..                    ...                    ...                  ...
# 959                   NaN                    NaN                  NaN
# 960                   NaN                    NaN                  NaN
# 961  Plácido Galindo · 70                    NaN                  NaN
# 962                   NaN                    NaN                  NaN
# 963                   NaN                    NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                  NaN
# 2                                                  NaN
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4    ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [964 rows x 44 columns]

# %%
df.shape
# Out:
# (964, 44)

# %%
#loop comprehensions
[age.append(random.randint(18,40)) for _ in range (964)]
print(f"age is now having{len(age)}")
# Out:
# age is now having964

# %%
age
# Out:
# [27,
#  19,
#  40,
#  28,
#  36,
#  29,
#  27,
#  22,
#  28,
#  20,
#  28,
#  40,
#  27,
#  19,
#  34,
#  25,
#  39,
#  27,
#  23,
#  40,
#  38,
#  35,
#  31,
#  35,
#  29,
#  31,
#  29,
#  22,
#  19,
#  33,
#  32,
#  26,
#  35,
#  39,
#  39,
#  22,
#  29,
#  18,
#  29,
#  36,
#  32,
#  36,
#  39,
#  24,
#  28,
#  29,
#  32,
#  18,
#  26,
#  36,
#  27,
#  25,
#  22,
#  33,
#  36,
#  34,
#  21,
#  37,
#  24,
#  31,
#  28,
#  30,
#  33,
#  28,
#  40,
#  18,
#  29,
#  20,
#  25,
#  34,
#  31,
#  21,
#  40,
#  22,
#  25,
#  38,
#  40,
#  32,
#  30,
#  38,
#  32,
#  33,
#  37,
#  30,
#  24,
#  20,
#  35,
#  37,
#  40,
#  30,
#  36,
#  20,
#  28,
#  25,
#  33,
#  28,
#  34,
#  22,
#  25,
#  39,
#  40,
#  22,
#  31,
#  31,
#  33,
#  39,
#  33,
#  18,
#  36,
#  35,
#  21,
#  28,
#  35,
#  38,
#  26,
#  26,
#  24,
#  38,
#  39,
#  34,
#  35,
#  24,
#  34,
#  40,
#  23,
#  37,
#  32,
#  37,
#  27,
#  34,
#  36,
#  40,
#  36,
#  38,
#  24,
#  39,
#  34,
#  20,
#  35,
#  32,
#  18,
#  37,
#  36,
#  28,
#  19,
#  33,
#  23,
#  19,
#  40,
#  33,
#  18,
#  23,
#  22,
#  35,
#  28,
#  35,
#  37,
#  30,
#  21,
#  21,
#  36,
#  35,
#  31,
#  37,
#  29,
#  25,
#  29,
#  28,
#  30,
#  38,
#  29,
#  32,
#  30,
#  40,
#  31,
#  23,
#  36,
#  27,
#  31,
#  32,
#  24,
#  21,
#  24,
#  21,
#  18,
#  22,
#  18,
#  40,
#  18,
#  40,
#  38,
#  23,
#  40,
#  37,
#  39,
#  39,
#  25,
#  18,
#  27,
#  37,
#  18,
#  33,
#  24,
#  40,
#  35,
#  28,
#  28,
#  20,
#  22,
#  37,
#  28,
#  21,
#  32,
#  18,
#  28,
#  35,
#  22,
#  22,
#  21,
#  22,
#  29,
#  29,
#  20,
#  18,
#  26,
#  24,
#  37,
#  32,
#  39,
#  37,
#  26,
#  22,
#  26,
#  30,
#  35,
#  36,
#  31,
#  28,
#  30,
#  39,
#  39,
#  21,
#  30,
#  36,
#  24,
#  39,
#  37,
#  24,
#  36,
#  35,
#  24,
#  34,
#  33,
#  32,
#  33,
#  39,
#  24,
#  25,
#  22,
#  38,
#  27,
#  26,
#  38,
#  23,
#  23,
#  39,
#  31,
#  21,
#  40,
#  19,
#  30,
#  29,
#  32,
#  31,
#  27,
#  24,
#  33,
#  37,
#  25,
#  35,
#  38,
#  37,
#  29,
#  36,
#  40,
#  19,
#  31,
#  21,
#  29,
#  36,
#  38,
#  23,
#  22,
#  30,
#  33,
#  27,
#  37,
#  22,
#  35,
#  22,
#  40,
#  24,
#  38,
#  27,
#  38,
#  26,
#  26,
#  35,
#  27,
#  32,
#  26,
#  25,
#  39,
#  37,
#  35,
#  31,
#  38,
#  26,
#  31,
#  19,
#  31,
#  35,
#  26,
#  22,
#  40,
#  23,
#  21,
#  23,
#  37,
#  20,
#  19,
#  37,
#  19,
#  24,
#  38,
#  27,
#  39,
#  35,
#  23,
#  26,
#  27,
#  37,
#  25,
#  29,
#  20,
#  37,
#  19,
#  35,
#  27,
#  38,
#  24,
#  40,
#  40,
#  40,
#  23,
#  24,
#  26,
#  34,
#  24,
#  32,
#  23,
#  34,
#  27,
#  19,
#  33,
#  37,
#  35,
#  29,
#  23,
#  35,
#  31,
#  27,
#  38,
#  30,
#  20,
#  20,
#  37,
#  20,
#  24,
#  28,
#  40,
#  23,
#  29,
#  19,
#  33,
#  27,
#  31,
#  20,
#  32,
#  36,
#  34,
#  34,
#  30,
#  23,
#  28,
#  39,
#  29,
#  39,
#  18,
#  39,
#  29,
#  30,
#  24,
#  40,
#  25,
#  30,
#  24,
#  28,
#  20,
#  19,
#  25,
#  26,
#  30,
#  36,
#  22,
#  19,
#  35,
#  25,
#  19,
#  35,
#  34,
#  25,
#  19,
#  32,
#  21,
#  39,
#  39,
#  24,
#  31,
#  23,
#  18,
#  21,
#  39,
#  32,
#  20,
#  40,
#  23,
#  40,
#  28,
#  30,
#  21,
#  21,
#  40,
#  24,
#  35,
#  21,
#  40,
#  22,
#  34,
#  35,
#  22,
#  37,
#  26,
#  28,
#  18,
#  23,
#  37,
#  18,
#  36,
#  22,
#  19,
#  31,
#  33,
#  21,
#  24,
#  35,
#  36,
#  30,
#  36,
#  24,
#  23,
#  22,
#  33,
#  40,
#  40,
#  18,
#  37,
#  28,
#  31,
#  27,
#  34,
#  39,
#  22,
#  18,
#  29,
#  22,
#  25,
#  28,
#  39,
#  31,
#  36,
#  37,
#  27,
#  21,
#  30,
#  22,
#  21,
#  18,
#  19,
#  27,
#  35,
#  32,
#  31,
#  36,
#  37,
#  22,
#  30,
#  31,
#  22,
#  37,
#  40,
#  38,
#  24,
#  19,
#  32,
#  27,
#  25,
#  19,
#  20,
#  38,
#  24,
#  26,
#  27,
#  35,
#  33,
#  38,
#  21,
#  37,
#  21,
#  19,
#  26,
#  39,
#  21,
#  27,
#  23,
#  18,
#  37,
#  28,
#  30,
#  37,
#  23,
#  29,
#  27,
#  22,
#  37,
#  40,
#  28,
#  21,
#  37,
#  28,
#  37,
#  26,
#  22,
#  21,
#  38,
#  23,
#  29,
#  21,
#  19,
#  39,
#  18,
#  22,
#  36,
#  38,
#  36,
#  30,
#  33,
#  34,
#  38,
#  38,
#  24,
#  23,
#  38,
#  28,
#  37,
#  35,
#  19,
#  26,
#  34,
#  26,
#  35,
#  30,
#  21,
#  34,
#  25,
#  36,
#  36,
#  34,
#  35,
#  31,
#  31,
#  40,
#  24,
#  26,
#  32,
#  18,
#  31,
#  30,
#  26,
#  23,
#  26,
#  18,
#  34,
#  32,
#  33,
#  33,
#  26,
#  24,
#  34,
#  24,
#  40,
#  40,
#  30,
#  19,
#  39,
#  38,
#  20,
#  26,
#  25,
#  27,
#  31,
#  38,
#  23,
#  38,
#  28,
#  24,
#  29,
#  36,
#  24,
#  38,
#  32,
#  31,
#  32,
#  31,
#  35,
#  36,
#  28,
#  37,
#  30,
#  19,
#  31,
#  40,
#  27,
#  24,
#  28,
#  39,
#  25,
#  20,
#  26,
#  32,
#  21,
#  32,
#  38,
#  31,
#  35,
#  21,
#  20,
#  32,
#  38,
#  39,
#  38,
#  20,
#  34,
#  30,
#  25,
#  24,
#  39,
#  37,
#  32,
#  36,
#  28,
#  21,
#  18,
#  27,
#  20,
#  21,
#  30,
#  39,
#  23,
#  30,
#  18,
#  32,
#  23,
#  36,
#  35,
#  18,
#  35,
#  33,
#  23,
#  33,
#  34,
#  33,
#  40,
#  35,
#  30,
#  20,
#  40,
#  26,
#  33,
#  19,
#  22,
#  40,
#  38,
#  22,
#  34,
#  32,
#  31,
#  24,
#  36,
#  40,
#  37,
#  32,
#  19,
#  20,
#  22,
#  20,
#  36,
#  32,
#  25,
#  40,
#  31,
#  25,
#  28,
#  32,
#  34,
#  37,
#  27,
#  28,
#  38,
#  20,
#  38,
#  34,
#  19,
#  30,
#  30,
#  32,
#  39,
#  18,
#  21,
#  35,
#  20,
#  30,
#  22,
#  20,
#  36,
#  27,
#  20,
#  21,
#  32,
#  37,
#  33,
#  34,
#  20,
#  19,
#  39,
#  19,
#  20,
#  40,
#  34,
#  30,
#  25,
#  25,
#  20,
#  40,
#  24,
#  19,
#  40,
#  18,
#  26,
#  38,
#  37,
#  38,
#  32,
#  19,
#  28,
#  40,
#  30,
#  33,
#  36,
#  22,
#  19,
#  38,
#  34,
#  33,
#  19,
#  30,
#  23,
#  33,
#  23,
#  36,
#  38,
#  40,
#  40,
#  39,
#  32,
#  31,
#  26,
#  37,
#  40,
#  37,
#  28,
#  37,
#  39,
#  37,
#  38,
#  39,
#  18,
#  20,
#  30,
#  19,
#  35,
#  24,
#  21,
#  28,
#  20,
#  40,
#  36,
#  28,
#  34,
#  34,
#  18,
#  27,
#  39,
#  33,
#  20,
#  36,
#  29,
#  39,
#  28,
#  37,
#  35,
#  28,
#  29,
#  27,
#  25,
#  30,
#  21,
#  27,
#  31,
#  24,
#  39,
#  31,
#  18,
#  32,
#  36,
#  33,
#  30,
#  18,
#  18,
#  25,
#  28,
#  35,
#  25,
#  19,
#  25,
#  26,
#  26,
#  18,
#  39,
#  24,
#  36,
#  29,
#  37,
#  29,
#  23,
#  33,
#  21,
#  38,
#  20,
#  37,
#  36,
#  29,
#  28,
#  26,
#  36,
#  35,
#  36,
#  29,
#  20,
#  29,
#  39,
#  28,
#  26,
#  25,
#  30,
#  40,
#  26,
#  22,
#  32,
#  36,
#  26,
#  21,
#  19,
#  22,
#  25,
#  24,
#  30,
#  38,
#  20,
#  29,
#  33,
#  21,
#  26,
#  22,
#  23,
#  38,
#  25,
#  34,
#  36,
#  31,
#  21,
#  30,
#  20,
#  21,
#  25,
#  39,
#  29,
#  30,
#  27,
#  30,
#  38,
#  30,
#  39,
#  18,
#  26,
#  38,
#  28,
#  28,
#  28,
#  38,
#  20,
#  24,
#  18,
#  37,
#  40,
#  23,
#  21,
#  29,
#  36,
#  32,
#  36,
#  21,
#  18,
#  40,
#  38,
#  35,
#  22,
#  24,
#  34,
#  21,
#  36,
#  25,
#  34,
#  35,
#  30,
#  37,
#  32,
#  35,
#  25,
#  28,
#  23,
#  31,
#  24,
#  36,
#  27,
#  25,
#  35,
#  28,
#  36,
#  28,
#  27,
#  23,
#  29,
#  26,
#  37,
#  29,
#  33,
#  39,
#  38,
#  18,
#  18,
#  39,
#  37,
#  34,
#  35,
#  19,
#  23,
#  19,
#  27,
#  33,
#  33,
#  40,
#  32,
#  28,
#  18,
#  21,
#  35,
#  31,
#  26,
#  23,
#  ...]

# %%
#Adding a new column to the dataframe
#syntax : df['New column name']=list/sec

# %%
df['YearsOfExperience']=age

# %%
df.shape
# Out:
# (964, 45)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#                        away_penalty_shootout_miss_long home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...           NaN
# 1                                                  NaN           NaN
# 2                                                  NaN           NaN
# 3                                                  NaN           NaN
# 4                                                  NaN           NaN
# ..                                                 ...           ...
# 959                                                NaN           NaN
# 960                                                NaN           NaN
# 961                                                NaN           NaN
# 962                                                NaN           NaN
# 963                                                NaN           NaN
#
#             away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN  Walid Cheddira · 90+3                  NaN
# ..                    ...                    ...                  ...
# 959                   NaN                    NaN                  NaN
# 960                   NaN                    NaN                  NaN
# 961  Plácido Galindo · 70                    NaN                  NaN
# 962                   NaN                    NaN                  NaN
# 963                   NaN                    NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                  NaN
# 2                                                  NaN
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4    ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long YearsOfExperience
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...                26
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...                40
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...                39
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...                25
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...                31
# ..                                                 ...               ...
# 959                                                NaN                34
# 960                                                NaN                27
# 961                                                NaN                37
# 962                                                NaN                39
# 963                                                NaN                22
#
# [964 rows x 45 columns]

# %%
df['ASP']=df['YearsOfExperience']-df['home_score']

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_red_card         away_red_card   home_yellow_red_card  \
# 0             NaN                   NaN                    NaN
# 1             NaN                   NaN                    NaN
# 2             NaN                   NaN                    NaN
# 3             NaN                   NaN                    NaN
# 4             NaN                   NaN  Walid Cheddira · 90+3
# ..            ...                   ...                    ...
# 959           NaN                   NaN                    NaN
# 960           NaN                   NaN                    NaN
# 961           NaN  Plácido Galindo · 70                    NaN
# 962           NaN                   NaN                    NaN
# 963           NaN                   NaN                    NaN
#
#     away_yellow_red_card                              home_yellow_card_long  \
# 0                    NaN  ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN  ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4                    NaN  ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                   ...                                                ...
# 959                  NaN                                                NaN
# 960                  NaN                                                NaN
# 961                  NaN                                                NaN
# 962                  NaN                                                NaN
# 963                  NaN                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long YearsOfExperience ASP
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...                26  23
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...                40  38
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...                39  37
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...                25  22
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...                31  30
# ..                                                 ...               ...  ..
# 959                                                NaN                34  33
# 960                                                NaN                27  25
# 961                                                NaN                37  34
# 962                                                NaN                39  36
# 963                                                NaN                22  18
#
# [964 rows x 46 columns]

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
df['ASP'].plot(kind='bar',color='black')
# Out:
# <Axes: >

# %%
df.plot(x='YearsOfExperience',y=['away_score','home_score'],kind='bar',color=['pink','skyblue'])
# Out:
# <Axes: xlabel='YearsOfExperience'>

# %%
#funtion to get a graph
def getgraph(DataFrame,Column1,Column2):
  from matplotlib import pyplot as plt

  # check length of c1 and c3
  if len(DataFrame[Column1])==len(DataFrame[Column2]):
    df.plot(x=Column1,y=Column2,kind='bar',color=['Black','Pink'])
  else:
    print("please check the column size once")

# %%
getgraph (df,'home_score','away_score')
