# %% [markdown]
# <a href="https://colab.research.google.com/github/ziyaashraf0907/python-mini-project/blob/main/Working_with_Pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Read the CSV file into a Pandas as pd
import pandas as pd

# %%
datasetpath ='/content/drive/MyDrive/retail'

# %%
df = pd.read_csv(datasetpath)

# %%
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount
# 0      Electronics         1    150      Credit      15.0
# 1             Toys         2    317       Debit      10.0
# ...

# %%
from datetime import datetime

# %%
df['TransactionDate']=pd.to_datetime(df['TransactionDate'])

# %%
#Initial Data Exploration
df.head(15)
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# 5           T006      2024-01-06      103        1836        515
# 6           T007      2024-01-07      103        1983        586
# 7           T008      2024-01-08      101        1806        569
# 8           T009      2024-01-09      101        1925        548
# 9           T010      2024-01-10      101        1711        565
# 10          T011      2024-01-11      103        1276        565
# 11          T012      2024-01-12      101        1486        523
# 12          T013      2024-01-13      103        1597        516
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    100 non-null    object
#  1   TransactionDate  100 non-null    object
#  2   StoreID          100 non-null    int64
#  3   CustomerID       100 non-null    int64
#  4   ProductID        100 non-null    int64
#  5   ProductCategory  100 non-null    object
#  6   Quantity         100 non-null    int64
#  7   Price            100 non-null    int64
#  8   PaymentType      100 non-null    object
#  9   Discount         75 non-null     float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#           StoreID   CustomerID   ProductID    Quantity      Price   Discount  \
# count  100.000000   100.000000  100.000000  100.000000  100.00000  100.00000
# mean   102.730000  1552.520000  554.390000    5.370000  282.15000    5.80000
# std      1.384291   268.295461   28.544098    3.013957  140.19938    5.93398
# min    101.000000  1013.000000  501.000000    1.000000   50.00000    0.00000
# 25%    101.000000  1310.250000  529.750000    3.000000  165.75000    0.00000
# 50%    103.000000  1534.000000  554.000000    5.500000  280.00000    5.00000
# 75%    104.000000  1800.750000  579.500000    8.000000  415.25000   10.00000
# max    105.000000  1983.000000  600.000000   10.000000  500.00000   15.00000
#
#          NetPrice    TotalSale
# count  100.000000   100.000000
# mean   266.211000  1456.037000
# std    135.318421  1188.135063
# min     50.000000    80.100000
# 25%    160.375000   453.150000
# 50%    251.750000  1133.700000
# 75%    390.250000  2157.375000
# ...

# %%
df.count()
# Out:
# TransactionID      100
# TransactionDate    100
# StoreID            100
# CustomerID         100
# ProductID          100
# ProductCategory    100
# Quantity           100
# Price              100
# PaymentType        100
# Discount           100
# NetPrice           100
# TotalSale          100
# dtype: int64

# %%
#Check for missing values in each column
missing_value=df.isnull().sum()

# %%
missing_value
# Out:
# TransactionID      0
# TransactionDate    0
# StoreID            0
# CustomerID         0
# ProductID          0
# ProductCategory    0
# Quantity           0
# Price              0
# PaymentType        0
# Discount           0
# NetPrice           0
# TotalSale          0
# dtype: int64

# %%
missing_value.value_counts()
# Out:
# 0    12
# Name: count, dtype: int64

# %%
#Ensure correct numerical formats for Quantity, Price, and Discount

df['Quantity']=pd.to_numeric(df['Quantity'])
df['Price']=pd.to_numeric(df['Price'])

df['Discount']=pd.to_numeric(df['Discount'])
df['Discount']=df['Discount'].fillna(0)

# %%
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount
# 0      Electronics         1    150      Credit      15.0
# 1             Toys         2    317       Debit      10.0
# ...

# %%
#Calculate NetPrice
df['NetPrice']=df['Price']*(1-df['Discount']/100)
#Calculate TotalSale
df['TotalSale']=df['Quantity']*df['NetPrice']

# %%
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  NetPrice  TotalSale
# 0      Electronics         1    150      Credit      15.0    127.50     127.50
# ...

# %%
#Data Filtering
filtered_df=df[df['TotalSale'] >=20]

# %%
filtered_df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  NetPrice  TotalSale
# 0      Electronics         1    150      Credit      15.0    127.50     127.50
# ...

# %%
#Data Type Conversion
filtered_df['PaymentType']=df['PaymentType'].astype('category')

# %%
filtered_df['PaymentType']
# Out:
# 0     Credit
# 1      Debit
# 2      Debit
# 3      Debit
# 4      Debit
#        ...
# 95      Cash
# 96     Debit
# 97    Credit
# 98    Credit
# 99    Credit
# Name: PaymentType, Length: 100, dtype: category
# Categories (3, object): ['Cash', 'Credit', 'Debit']

# %%
#Grouping and Aggregation
grouped_df = df.groupby('ProductCategory')[['Quantity', 'TotalSale']].sum().reset_index()
grouped_df = grouped_df.sort_values(by='TotalSale', ascending=False)

# %%
top_3_categories = grouped_df.head(3)

# %%
top_3_categories
# Out:
#   ProductCategory  Quantity  TotalSale
# 4            Toys       137   44326.35
# 2       Furniture       130   39655.55
# 0         Apparel       117   28055.35

# %%
grouped_df = df.groupby(['StoreID', 'ProductCategory'])['TotalSale'].mean().reset_index()

# %%
#Group the filtered data by both StoreID and ProductCategory

multi_grouped = filtered_df.groupby(['StoreID', 'ProductCategory']).agg(
    AverageTotalSale=('TotalSale', 'mean')
).reset_index()

# %%
grouped_df
# Out:
#     StoreID ProductCategory    TotalSale
# 0       101         Apparel  1344.550000
# 1       101     Electronics  1128.916667
# 2       101       Furniture  1317.943750
# 3       101            Toys  2227.016667
# 4       102         Apparel  1452.180000
# 5       102     Electronics   591.380000
# 6       102       Furniture  2565.900000
# 7       102         Grocery   171.900000
# 8       102            Toys  1036.557143
# 9       103         Apparel  1021.950000
# 10      103     Electronics   817.666667
# 11      103       Furniture  1560.771429
# 12      103         Grocery   954.850000
# 13      103            Toys  1239.180000
# 14      104         Apparel   722.000000
# 15      104     Electronics   852.333333
# 16      104       Furniture  1528.928571
# 17      104         Grocery  1118.833333
# 18      104            Toys  1367.700000
# 19      105         Apparel  2398.450000
# 20      105     Electronics  2313.500000
# 21      105       Furniture  1176.150000
# ...

# %%
top_categories_df
# Out:
#     StoreID ProductCategory  TotalSale
# 73      101            Toys     3809.7
# 65      102       Furniture     3519.0
# 46      103       Furniture     4490.0
# 33      104       Furniture     4320.0
# 56      105            Toys     4880.0

# %%
multi_grouped
# Out:
#     StoreID ProductCategory  AverageTotalSale
# 0       101         Apparel       1344.550000
# 1       101     Electronics       1128.916667
# 2       101       Furniture       1317.943750
# 3       101            Toys       2227.016667
# 4       102         Apparel       1452.180000
# 5       102     Electronics        591.380000
# 6       102       Furniture       2565.900000
# 7       102         Grocery        171.900000
# 8       102            Toys       1036.557143
# 9       103         Apparel       1021.950000
# 10      103     Electronics        817.666667
# 11      103       Furniture       1560.771429
# 12      103         Grocery        954.850000
# 13      103            Toys       1239.180000
# 14      104         Apparel        722.000000
# 15      104     Electronics        852.333333
# 16      104       Furniture       1528.928571
# 17      104         Grocery       1118.833333
# 18      104            Toys       1367.700000
# ...

# %%
# For each store (StoreID), determine which product category has the highest average TotalSale
store_insights = multi_grouped.loc[multi_grouped.groupby('StoreID')['AverageTotalSale'].idxmax()]

# %%
# Prepare and print a summary DataFrame
summary_df = store_insights[['StoreID', 'ProductCategory', 'AverageTotalSale']]

# %%
summary_df
# Out:
#     StoreID ProductCategory  AverageTotalSale
# 3       101            Toys       2227.016667
# 6       102       Furniture       2565.900000
# 11      103       Furniture       1560.771429
# 16      104       Furniture       1528.928571
# 23      105            Toys       4048.000000

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(filtered_df['Quantity'], filtered_df['NetPrice'], color='coral', alpha=0.5)
plt.xlabel('Quantity')
plt.ylabel('Net Price')
plt.title('Quantity vs Net Price')
plt.show()

# %%
plt.bar(grouped_df.index, grouped_df['TotalSale'], color='skyblue')
plt.xlabel('Product Category')
plt.ylabel('Total Sales')
plt.title('Total Sales per Product Category')
plt.show()

# %%
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  NetPrice  TotalSale
# 0      Electronics         1    150      Credit      15.0    127.50     127.50
# ...

# %%
total_revenue=df['TotalSale'].sum()

# %%
total_revenue
# Out:
# 145603.69999999998

# %%
most_purchased_product=df['ProductCategory'].mode()[0]

# %%
most_purchased_product
# Out:
# 'Furniture'

# %%
average_transaction=df['TotalSale'].mean()

# %%
average_transaction
# Out:
# 1456.0369999999998

# %%
filter1=df[df['TotalSale']>200]

# %%
filter1
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# 5           T006      2024-01-06      103        1836        515
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  NetPrice  TotalSale
# 1             Toys         2    317       Debit      10.0    285.30     570.60
# ...

# %%
top_3_customers=df.groupby("CustomerID")['TotalSale'].sum().nlargest(3)

# %%
top_3_customers
# Out:
# CustomerID
# 1734    5375.0
# 1396    4742.0
# 1532    4490.0
# Name: TotalSale, dtype: float64
