# %% [markdown]
# <a href="https://colab.research.google.com/github/ziyaashraf0907/python-mini-project/blob/main/ML1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
import random
x = []
y = []
[x.append(random.randint(0,25)) for _ in range(10)]
[y.append(random.randint(0,25)) for _ in range(10)]
print(x)
print(y)
# Out:
# [17, 18, 24, 1, 10, 13, 2, 22, 11, 3]
# [8, 11, 6, 12, 13, 15, 18, 9, 19, 1]

# %%
plt.plot(x)

# %%
plt.plot(y)

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y)
plt.scatter(x,y)
