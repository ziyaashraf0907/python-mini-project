# %% [markdown]
# <a href="https://colab.research.google.com/github/ziyaashraf0907/python-mini-project/blob/main/DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
a1=[]
a2=[]
a3=[]
a4=[]
a5=[]

# %%
for _ in range(100):
    a1.append(random.randint(0,100))
    a2.append(random.randint(50,70))
    a3.append(random.randint(10,20))
    a4.append(random.randint(5,30))
    a5.append(random.randint(20,88))

# %%
df = {
      'grade':a1,
      'weight':a2,
      'friends':a3,
      'cousins':a4,
      'projects':a5
     }

# %%
import pandas as pd

# %%
df1=pd.DataFrame(df)

# %%
df1
# Out:
#       grade  weight  friends  cousins  projects
# 0        86      62       12       26        26
# 1        70      68       14       10        63
# 2        16      57       18       21        23
# 3        65      58       13        9        32
# 4        13      60       14       11        43
# ...     ...     ...      ...      ...       ...
# 1195      4      67       19       22        57
# 1196     44      59       11       23        84
# 1197     69      66       17       22        65
# 1198      8      63       17       17        77
# 1199     93      52       15       10        81
#
# [1200 rows x 5 columns]

# %%
df1.describe()
# Out:
#              grade       weight      friends      cousins     projects
# count  1200.000000  1200.000000  1200.000000  1200.000000  1200.000000
# mean     48.709167    59.895833    15.086667    17.657500    54.022500
# std      29.036078     6.110054     3.171362     7.427281    19.370114
# min       0.000000    50.000000    10.000000     5.000000    20.000000
# 25%      24.000000    55.000000    12.000000    12.000000    38.000000
# 50%      47.000000    60.000000    15.000000    18.000000    54.000000
# 75%      74.000000    65.000000    18.000000    24.000000    71.000000
# max     100.000000    70.000000    20.000000    30.000000    88.000000

# %%
df1['grade'].count()
# Out:
# 1200

# %%
df1['grade'].count
# Out:
# <bound method Series.count of 0       86
# 1       70
# 2       16
# 3       65
# 4       13
#         ..
# 1195     4
# 1196    44
# 1197    69
# 1198     8
# 1199    93
# Name: grade, Length: 1200, dtype: int64>

# %%
#Filter1
friend15=df1['friends']>15

# %%
df1[friend15]
# Out:
#       grade  weight  friends  cousins  projects
# 2        16      57       18       21        23
# 5        62      54       17       25        34
# 7        70      60       20       27        71
# 14        9      57       19       15        39
# 15       39      59       18       21        65
# ...     ...     ...      ...      ...       ...
# 1186     77      63       19       24        73
# 1194     81      52       17       20        36
# 1195      4      67       19       22        57
# 1197     69      66       17       22        65
# 1198      8      63       17       17        77
#
# [569 rows x 5 columns]

# %%
df1['friends'].describe()
# Out:
# count    1200.000000
# mean       15.086667
# std         3.171362
# min        10.000000
# 25%        12.000000
# 50%        15.000000
# 75%        18.000000
# max        20.000000
# Name: friends, dtype: float64

# %%
#Filter2
grade50=df1['grade']>50

# %%
df1[grade50]
# Out:
#       grade  weight  friends  cousins  projects
# 0        86      62       12       26        26
# 1        70      68       14       10        63
# 3        65      58       13        9        32
# 5        62      54       17       25        34
# 7        70      60       20       27        71
# ...     ...     ...      ...      ...       ...
# 1192     76      55       12        5        45
# 1193     69      58       11       16        40
# 1194     81      52       17       20        36
# 1197     69      66       17       22        65
# 1199     93      52       15       10        81
#
# [574 rows x 5 columns]

# %%
df1[friend15 & grade50]
# Out:
#       grade  weight  friends  cousins  projects
# 5        62      54       17       25        34
# 7        70      60       20       27        71
# 25       76      58       18       19        86
# 26       64      63       17       24        35
# 32       83      59       18       21        48
# ...     ...     ...      ...      ...       ...
# 1176     76      67       17       14        77
# 1183     64      70       17       10        77
# 1186     77      63       19       24        73
# 1194     81      52       17       20        36
# 1197     69      66       17       22        65
#
# [274 rows x 5 columns]

# %%
df1[friend15 & grade50]['friends'].value_counts()
# Out:
# friends
# 17    67
# 16    54
# 18    53
# 20    51
# 19    49
# Name: count, dtype: int64

# %%
df1[friend15 & grade50]['friends']
# Out:
# 5       17
# 7       20
# 25      18
# 26      17
# 32      18
#         ..
# 1176    17
# 1183    17
# 1186    19
# 1194    17
# 1197    17
# Name: friends, Length: 274, dtype: int64

# %%
pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
df1[friend15 & grade50].plot()
# Out:
# <Axes: >

# %%
# %matplotlib inline

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1[friend15 & grade50].plot()
# Out:
# <Axes: >

# %%
df1[friend15 & grade50].plot(x = 'grade',y = 'projects')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend15 & grade50].plot(x = 'grade',y = 'projects',kind = 'box')
# Out:
# <Axes: >

# %%
df1[friend15 & grade50].plot(x = 'grade',y = 'projects',kind = 'bar')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend15 & grade50].plot(x = 'grade',y = 'projects',kind = 'scatter')
# Out:
# <Axes: xlabel='grade', ylabel='projects'>

# %%
 df1[friend15 & grade50].plot(x = 'grade',y = 'projects',kind = 'area')
# Out:
# <Axes: xlabel='grade'>

# %%
pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
df1[friend15 & grade50].plot(x = ['grade','friends'],y = ['projects','cousins'],kind = 'scatter',title = 'sample Graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend(['Test data'])
plt.show()

# %%
fdf = df1[friend15 & grade50]

# %%
fdf
# Out:
#       grade  weight  friends  cousins  projects
# 5        62      54       17       25        34
# 7        70      60       20       27        71
# 25       76      58       18       19        86
# 26       64      63       17       24        35
# 32       83      59       18       21        48
# ...     ...     ...      ...      ...       ...
# 1176     76      67       17       14        77
# 1183     64      70       17       10        77
# 1186     77      63       19       24        73
# 1194     81      52       17       20        36
# 1197     69      66       17       22        65
#
# [274 rows x 5 columns]

# %%
df1.to_csv('/feb6TestData.csv')
